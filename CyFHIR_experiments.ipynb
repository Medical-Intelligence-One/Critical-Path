# %% [markdown]
# # FHIR U.S. Core data in a graph using CyFHIR

# %% [markdown]
# Download data from https://inferno.healthit.gov/inferno (see link to test data under the Sample tab).
# Follow instructions to set up CyFHIR at https://github.com/Optum/CyFHIR

# %%
import json

# %%
with open('/media/sata_1TB_internal/uscore-testing-data-12-07-2020/raw/fhir/Harlan808_Muller251_31aa3086-c79a-ecf0-a02e-e36710b15e0b.json', 'r') as file:
    data = file.read()

# %%
data_escaped = data.replace('"','\\"')

# %%
with open('test_FHIR.json', 'w') as file:
    file.write(data_escaped)

# %%
json.loads(data)['entry'][0]['resource']['text']['div']
# Out:
# '<div xmlns="http://www.w3.org/1999/xhtml">Generated by <a href="https://github.com/synthetichealth/synthea">Synthea</a>.Version identifier: v2.6.1-3-g50f4f58f\n .   Person seed: 6184334798486509461  Population seed: 3</div>'
