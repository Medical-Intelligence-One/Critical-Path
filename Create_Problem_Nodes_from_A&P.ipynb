# %% [markdown]
# # Version 1
# Strategy: Load all UMLS strings into memory and perform custom-built search for UMLS concepts
# Performance: ~40 seconds to extract all problems from a single patient's notes, inappropriately extracts some concepts

# %% [markdown]
# ## Instructions
# Given a jupyter notebook with code to create a python list of strings containing the Assessment and Plan portion of physician's notes, extract the patient's problems. At this early step, don't worry if your code also extracts items which are really part of the "housekeeping" items that are sometimes listed at the very end of the note.
#
# #### Expected output:
# A list of problems that each patient has.
#
# You can use a rules-based approach, medspacy, medcat, metamap, UMLS, bioportal annotator, or anything else you think will get the job done.

# %% [markdown]
# ## Iteration-independent code

# %%
import pandas as pd
pd.set_option('display.max_colwidth', None)
import time
import re
import pprint
import numpy as np
import multiprocessing
from multiprocessing import  Pool

# %%
# Runing this cell will ask you to provide the database password. If you need the password, email Tim McLerran at tmclerran@gmail.com to provide evidence 
# that you have been granted access to MIMIC-III data by physionet. If you are unsure how to proceed, just ask the #nlp channel on Slack
import getpass
password = getpass.getpass("\nPlease enter the Neo4j database password to continue \n")
# Out:
# Please enter the Neo4j database password to continue
#  ···············

# %%
# Create a connection to the working group's Neo4j database of MIMIC-III data
from neo4j import GraphDatabase
driver=GraphDatabase.driver(uri="bolt://localhost:7687", auth=('neo4j',password))
session=driver.session()

# %%
query = '''
MATCH (n:Noteevents)
WHERE n.CATEGORY = "Physician "
RETURN DISTINCT(n.SUBJECT_ID) as subject_id
ORDER BY subject_id'''
patients = session.run(query)
patients = pd.DataFrame([dict(record) for record in patients])
print(patients.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7623 entries, 0 to 7622
# Data columns (total 1 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   subject_id  7623 non-null   object
# dtypes: object(1)
# memory usage: 59.7+ KB
# None

# %% [markdown]
# ## Iterate over patients to create CSV files to batch import problems

# %%
# Cypher query to obtain all physician notes for a patient with a given subject_id
query = '''
MATCH (n:Noteevents)
WHERE n.CATEGORY = "Physician "
RETURN DISTINCT(n.TEXT) AS note, n.STORETIME as storetime, n.SUBJECT_ID as subject_id, n.ROW_ID as note_id
ORDER BY subject_id, storetime'''

# %%
def get_notes(query):

    # Execute the cypher query to obtain physician notes in a Neo4j object
    data = session.run(query)

    # Convert the neo4j object into a dataframe
    df = pd.DataFrame([dict(record) for record in data])

    # Define a function that takes a full physician's note and returns only the Assessment and Plan portion
    def isolate_AP(note):
        # Define a regex pattern to isolate the Assessment and Plan portion of each note
        try:
            pattern = re.compile(r'(Assessment and Plan.*)ICU Care', re.DOTALL)
            return re.search(pattern, note).group(1)
        except:
            pattern = re.compile(r'(Assessment and Plan.*)ICU \[\*\*', re.DOTALL)
            if re.search(pattern, note) != None:
                return re.search(pattern, note).group(1)
            else:
                return 'No AP isolated'

    # Apply the function that isolates AP to the column of the dataframe containing notes
    df['note'] = df['note'].apply(isolate_AP)

    # Check the output
    return df

# %%
start_time = time.time()
df = get_notes(query)
print("Total runtime:", time.time() - start_time, "seconds")
df.info()
# Out:
# Total runtime: 11.331737995147705 seconds
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 141624 entries, 0 to 141623
# Data columns (total 4 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   note        141624 non-null  object
#  1   storetime   141624 non-null  object
#  2   subject_id  141624 non-null  object
#  3   note_id     141624 non-null  object
# dtypes: object(4)
# memory usage: 4.3+ MB

# %%
df[df['note'] == 'No AP isolated']
# Out:
#                   note            storetime subject_id note_id
# 175     No AP isolated  2129-12-31 23:20:53      10428  363396
# 176     No AP isolated  2130-01-01 01:24:42      10428  363403
# 199     No AP isolated  2165-05-06 01:57:11      10502  405218
# 213     No AP isolated  2166-05-23 02:34:57      10686  406408
# 242     No AP isolated  2140-10-12 10:48:07      10774  345108
# ...                ...                  ...        ...     ...
# 141425  No AP isolated  2153-04-20 12:03:37      99912  524081
# 141438  No AP isolated  2153-04-22 08:06:06      99912  524592
# 141442  No AP isolated  2153-04-22 10:47:21      99912  524631
# 141517  No AP isolated  2161-02-17 13:59:34      99944  627286
# 141532  No AP isolated  2161-02-20 11:40:55      99944  627837
#
# [10503 rows x 4 columns]

# %% [markdown]
# To-do:
# - Remake str_to_CUI as str_to_AUI using MRCONSO_for_import
# - change CUI to AUI in all the code in this notebook
# - recreate the problems_from_notes file
# - re-import problems

# %%
# Load the table of all strings in the UMLS with their associated CUI and semantic type
str_to_CUI = pd.read_csv('/home/tim/Documents/GrApH_AI/Data/str_to_CUI.csv', encoding='utf-8')
str_to_CUI.dropna(inplace=True)
str_to_CUI.tail()
# Out:
#                 STR       CUI                     STY
# 14305583    ﾜﾝﾌｶｲｶﾝ  C0877610         Sign or Symptom
# 14305584     ﾜﾝﾍﾝｹｲ  C0919717  Anatomical Abnormality
# 14305585  ﾜﾝﾍﾝｹｲNOS  C0919717  Anatomical Abnormality
# 14305586   ﾜﾝﾎｳｿｳｴﾝ  C0562422     Disease or Syndrome
# 14305587    ﾜﾝﾚｯｼｮｳ  C0432974     Injury or Poisoning

# %%
# Define a function that conducts a fast binary search on a sorted column of a dataframe, returning only full match results.

def binary_search(dataframe, column, target):
    range_start = 0
    range_end = len(dataframe)-1
    while range_start < range_end:
        range_middle = (range_end + range_start) // 2
        value = dataframe.iloc[range_middle][column]
        if value == target:
            return dataframe.iloc[range_middle]
        elif value < target:
            # Discard the first half of the range
            range_start = range_middle + 1
        else:
            # Discard the second half of the range
            range_end = range_middle - 1
    # At this point range_start = range_end
    value = dataframe.iloc[range_start][column]
#     return value
    if value == target:
        return dataframe.iloc[range_start]
    else:
        return 0

# %%
# Define a function which takes a string and returns the problem identified at the start of the string

def text_to_CUIs(text):
    
    # Remove any non-alphanumeric characters, set the encodning to unicode, and split the text into a list of words
    text = re.sub('[\W_]+', ' ', text, flags=re.UNICODE)
    text = text.strip()
    text = text.split(' ')
    
    cui = None
    
    # Iterate through the beginning of the list of words to find the largest set of consecutive words that match CUI-associated strings
    
    for i in reversed(range(1,7)):
        term = ' '.join(text[:i])
        frame = binary_search(dataframe = str_to_CUI, column = 'STR', target = term)
        
        if type(frame) == int:
            frame = binary_search(dataframe = str_to_CUI, column = 'STR', target = term.lower())
            if type(frame) == int:
                frame = binary_search(dataframe = str_to_CUI, column = 'STR', target = term.upper())
                if type(frame) == int:
                    frame = binary_search(dataframe = str_to_CUI, column = 'STR', target = term.title())
                    if type(frame) == int:
                        pass
                      
                    else:
                        if frame['STY'] in ['Disease or Syndrome', 'Pathologic Function', 'Neoplastic Process', 'Sign or Symptom', 'Injury or Poisoning', 'Mental or Behavioral Dysfunction']:
                            return frame['CUI']
                else:
                    if frame['STY'] in ['Disease or Syndrome', 'Pathologic Function', 'Neoplastic Process', 'Sign or Symptom', 'Injury or Poisoning', 'Mental or Behavioral Dysfunction']:
                        return frame['CUI']
            else:
                if frame['STY'] in ['Disease or Syndrome', 'Pathologic Function', 'Neoplastic Process', 'Sign or Symptom', 'Injury or Poisoning', 'Mental or Behavioral Dysfunction']:
                    return frame['CUI']
        else:
            if frame['STY'] in ['Disease or Syndrome', 'Pathologic Function', 'Neoplastic Process', 'Sign or Symptom', 'Injury or Poisoning', 'Mental or Behavioral Dysfunction']:
                return frame['CUI']
        
            break

# %%
# Define a function that accepts an Assessment and Plan and extracts the problems listed
def AP_to_problems(AP):
    problem_set = set([])
    if AP != 'No AP isolated':
        rows_list = AP.split('\n')
        for row in rows_list:
            cui = text_to_CUIs(row)
            if cui != None:
                problem_set.add(cui)
        return problem_set
    else:
        return problem_set
        
# Define a function that applies the AP_to_problems function to the note column of a 
# dataframe and adds the result as a new "problem" column to the dataframe
def add_problems_col(df):
    df['problems'] = df['note'].apply(AP_to_problems)
    return df

# Define a function that uses parallel processing to perform a given function 
# on a given dataframe
def parallelize_dataframe(df, func):
#     n_cores = multiprocessing.cpu_count()
    n_cores = 11
    df_split = np.array_split(df, n_cores)
    pool = Pool(n_cores)
    df = pd.concat(pool.map(func, df_split))
    pool.close()
    pool.join()
    return df

start_time = time.time()

# Run the function that adds a "problems" column to the dataframe, using the 
# parallel processing function
df = parallelize_dataframe(df, add_problems_col)

print("Total runtime:", time.time() - start_time, "seconds")
# Out:
# Total runtime: 39277.384462594986 seconds

# %% [markdown]
# |Number of cores|Seconds to extract AP from 1000 notes|
# |---|---|
# |8|322|
# |10|304|
# |11|295|
# |12|302|

# %%
# # Inspect the results of problem extraction
# for i in range(df[:4].shape[0]):
#     print(df.iloc[i]['note'])
#     for problem in df.iloc[i]['problems']:
#         print(problem)
#     print('\n------------------------------------------------')
# Out:
# Assessment and Plan
#    85F with h/o ESRD on HD, presenting with hypotension.
#    .
#    # hypotension - consistent with hypovolemic shock given clinical
#    history, HCT changes may not reflect acuity of bleed.  remains
#    hypotensive despite 3U PRBC in ED and 1L IVF, in setting of unclear
#    volume loss.  given h/o CHF current CVP is more consistent cardiogenic
#    shock, also cool extremities, though this could also represent
#    peripheral vasoconstriction.  while less likely given lack of fever,
#    leukocytosis, sepsis is also a consideration.
#    - transduce CVP from cordis -> 19, c/w cardiogenic shock.
#    - check SvO2 to confirm decreased CO, if present, consider swan, for
#    pressor guided diuresis.
#    - check TTE to evaluate [**Last Name (LF) **], [**First Name3 (LF) 300**], valves.
#    - start amio gtt for tachycardia.
#    - transfuse PRBC and IVF NS if CVP<10.
#    - titrate levophed gtt for MAP>65, could consider neo gtt given
#    tachycardia, however must consider severe PVD, and risk of limb
#    necrosis.
#    - cover with vancomycin for now given L LE wounds.
#    - check BCx, UCx.
#    .
#    # respiratory failure - pt intubated in the setting of prolonged
#    hypotension, resulting on altered mental status, and concern over
#    patient's airway.  pre-intubation ABG 7.35/46/340, consistent with good
#    lung mechanics.
#    - wean sedation as tolerated.
#    - wean vent support.
#    .
#    # ?s/p fall - by report, fell out of bed causing HD line to be
#    displaced.
#    - c-collar.
#    - plain films of hips, ct neck when more stable.
#    .
#    # anemia - baseline HCT ~30 at NEBH per OMR in 5/09per OMR (last in
#    [**2139**]).
#    - as above, transfuse for goal HCT>28, or CVP<[**10-8**].
#    .
#    # DM - cover with SSI while inpatient.
#    .
#    # ESRD on HD - will need to touch base with family re where dialysis
#    occurs, and which days.
#    - consult renal re hd.
#    - renally dose meds.
#    .
#    # HTN - hold anti-hypertensive in setting of hypotension.
#    .
#    # CHF (EF 50-60%) - clinically euvolemic/dry.
#    - hold lasix, ACE.
#    .
#    # CAD s/p MI, CABG - with h/o aflutter.
#    - hold aspirin in setting of bleeding.
#    .
#    # DM2 - cover with SSI while inpatient.
#    .
#    # PVD - s/p aortofemoral bypass.
#    - continue aspirin as above.
#    .
#    # FEN: No IVF, cardiac, diabetic diet.
#    .
#    # Prophylaxis: pnumoboots.
#    # Access: TLC, PIV.
#    # Code: DNR, and if extubated, does not want re-intubation.  Plan is
#    for CMO if pt does not appear to be improving quickly.
#    # Communication: With family. Husband [**Name (NI) 9243**]: [**Telephone/Fax (1) 9244**], [**Name2 (NI) 9245**]
#    [**Last Name (NamePattern1) 9246**] (DTR): [**Telephone/Fax (1) 9247**] or [**Telephone/Fax (1) 9248**]
#    # Disposition: pending above
#
# ['hypotensive', 'Pathologic Function', 'C0857353']
# ['shock', 'Pathologic Function', 'C0036974']
# ['leukocytosis', 'Disease or Syndrome', 'C0023518']
# ['respiratory failure', 'Disease or Syndrome', 'C1145670']
# ['anemia', 'Disease or Syndrome', 'C0002871']
# ['ESRD', 'Disease or Syndrome', 'C0022661']
# ['HTN', 'Disease or Syndrome', 'C0020538']
# ['CHF', 'Disease or Syndrome', 'C0018802']
#
# ------------------------------------------------
# Assessment and Plan
#    85F with h/o ESRD on HD, presenting with hypotension.
#    .
#    # hypotension - consistent with hypovolemic shock given clinical
#    history, HCT changes may not reflect acuity of bleed.  remains
#    hypotensive despite 3U PRBC in ED and 1L IVF, in setting of unclear
#    volume loss.  given h/o CHF current CVP is more consistent cardiogenic
#    shock, also cool extremities, though this could also represent
#    peripheral vasoconstriction.  while less likely given lack of fever,
#    leukocytosis, sepsis is also a consideration.
#    - transduce CVP from cordis -> 19, c/w cardiogenic shock.
#    - check SvO2 to confirm decreased CO, if present, consider swan, for
#    pressor guided diuresis.
#    - check TTE to evaluate [**Last Name (LF) **], [**First Name3 (LF) 300**], valves.
#    - start amio gtt for tachycardia.
#    - transfuse PRBC and IVF NS if CVP<10.
#    - titrate levophed gtt for MAP>65, could consider neo gtt given
#    tachycardia, however must consider severe PVD, and risk of limb
#    necrosis.
#    - cover with vancomycin for now given L LE wounds.
#    - check BCx, UCx.
#    .
#    # respiratory failure - pt intubated in the setting of prolonged
#    hypotension, resulting on altered mental status, and concern over
#    patient's airway.  pre-intubation ABG 7.35/46/340, consistent with good
#    lung mechanics.
#    - wean sedation as tolerated.
#    - wean vent support.
#    .
#    # ?s/p fall - by report, fell out of bed causing HD line to be
#    displaced.
#    - c-collar.
#    - plain films of hips, ct neck when more stable.
#    .
#    # anemia - baseline HCT ~30 at NEBH per OMR in 5/09per OMR (last in
#    [**2139**]).
#    - as above, transfuse for goal HCT>28, or CVP<[**10-8**].
#    .
#    # DM - cover with SSI while inpatient.
#    .
#    # ESRD on HD - will need to touch base with family re where dialysis
#    occurs, and which days.
#    - consult renal re hd.
#    - renally dose meds.
#    .
#    # HTN - hold anti-hypertensive in setting of hypotension.
#    .
#    # CHF (EF 50-60%) - clinically euvolemic/dry.
#    - hold lasix, ACE.
#    .
#    # CAD s/p MI, CABG - with h/o aflutter.
#    - hold aspirin in setting of bleeding.
#    .
#    # DM2 - cover with SSI while inpatient.
#    .
#    # PVD - s/p aortofemoral bypass.
#    - continue aspirin as above.
#    .
#    # FEN: No IVF, cardiac, diabetic diet.
#    .
#    # Prophylaxis: pnumoboots.
#    # Access: TLC, PIV.
#    # Code: DNR, and if extubated, does not want re-intubation.  Plan is
#    for CMO if pt does not appear to be improving quickly.
#    # Communication: With family. Husband [**Name (NI) 9243**]: [**Telephone/Fax (1) 9244**], [**Name2 (NI) 9245**]
#    [**Last Name (NamePattern1) 9246**] (DTR): [**Telephone/Fax (1) 9247**] or [**Telephone/Fax (1) 9248**]
#    # Disposition: pending above
#
# ['hypotensive', 'Pathologic Function', 'C0857353']
# ['shock', 'Pathologic Function', 'C0036974']
# ['leukocytosis', 'Disease or Syndrome', 'C0023518']
# ['respiratory failure', 'Disease or Syndrome', 'C1145670']
# ['anemia', 'Disease or Syndrome', 'C0002871']
# ['ESRD', 'Disease or Syndrome', 'C0022661']
# ['HTN', 'Disease or Syndrome', 'C0020538']
# ['CHF', 'Disease or Syndrome', 'C0018802']
#
# ------------------------------------------------
# Assessment and Plan
#  ALTERED MENTAL STATUS (NOT DELIRIUM)
#  SHOCK, CARDIOGENIC
#  IMPAIRED SKIN INTEGRITY
#  AIRWAY, INABILITY TO PROTECT (RISK FOR ASPIRATION, ALTERED GAG,
#    AIRWAY CLEARANCE, COUGH)
#
# ['altered mental status', 'Mental or Behavioral Dysfunction', 'C0278061']
# ['shock cardiogenic', 'Pathologic Function', 'C0036980']
#
# ------------------------------------------------
# Assessment and Plan
#    85F with h/o ESRD on HD, presenting with hypotension.
#    .
#    # hypotension - consistent with hypovolemic shock given clinical
#    history, HCT changes may not reflect acuity of bleed.  remains
#    hypotensive despite 3U PRBC in ED and 1L IVF, in setting of unclear
#    volume loss.  given h/o CHF current CVP is more consistent cardiogenic
#    shock, also cool extremities, though this could also represent
#    peripheral vasoconstriction.  while less likely given lack of fever,
#    leukocytosis, sepsis is also a consideration.
#    - transduce CVP from cordis -> 19, c/w cardiogenic shock.
#    - check SvO2 to confirm decreased CO, if present, consider swan, for
#    pressor guided diuresis.
#    - check TTE to evaluate [**Last Name (LF) **], [**First Name3 (LF) 300**], valves.
#    - start amio gtt for tachycardia.
#    - transfuse PRBC and IVF NS if CVP<10.
#    - titrate levophed gtt for MAP>65, could consider neo gtt given
#    tachycardia, however must consider severe PVD, and risk of limb
#    necrosis.
#    - cover with vancomycin for now given L LE wounds.
#    - check BCx, UCx.
#    .
#    # respiratory failure - pt intubated in the setting of prolonged
#    hypotension, resulting on altered mental status, and concern over
#    patient's airway.  pre-intubation ABG 7.35/46/340, consistent with good
#    lung mechanics.
#    - wean sedation as tolerated.
#    - wean vent support.
#    .
#    # ?s/p fall - by report, fell out of bed causing HD line to be
#    displaced.
#    - c-collar.
#    - plain films of hips, ct neck when more stable.
#    .
#    # anemia - baseline HCT ~30 at NEBH per OMR in 5/09per OMR (last in
#    [**2139**]).
#    - as above, transfuse for goal HCT>28, or CVP<[**10-8**].
#    .
#    # DM - cover with SSI while inpatient.
#    .
#    # ESRD on HD - will need to touch base with family re where dialysis
#    occurs, and which days.
#    - consult renal re hd.
#    - renally dose meds.
#    .
#    # HTN - hold anti-hypertensive in setting of hypotension.
#    .
#    # CHF (EF 50-60%) - clinically euvolemic/dry.
#    - hold lasix, ACE.
#    .
#    # CAD s/p MI, CABG - with h/o aflutter.
#    - hold aspirin in setting of bleeding.
#    .
#    # DM2 - cover with SSI while inpatient.
#    .
#    # PVD - s/p aortofemoral bypass.
#    - continue aspirin as above.
#    .
#    # FEN: No IVF, cardiac, diabetic diet.
#
# ['hypotensive', 'Pathologic Function', 'C0857353']
# ['shock', 'Pathologic Function', 'C0036974']
# ['leukocytosis', 'Disease or Syndrome', 'C0023518']
# ['respiratory failure', 'Disease or Syndrome', 'C1145670']
# ['anemia', 'Disease or Syndrome', 'C0002871']
# ['ESRD', 'Disease or Syndrome', 'C0022661']
# ['HTN', 'Disease or Syndrome', 'C0020538']
# ['CHF', 'Disease or Syndrome', 'C0018802']
#
# ------------------------------------------------

# %% [markdown]
# To-do:
# - When tidying up to make the final version of code to run: in the AP_to_CUIs function, change the problem list of lists into a set of CUIs and change the write-out code to iterate through the set instead of iterating through the list of lists and then the set

# %%
df.shape[0]
# Out:
# 141624

# %%
df.iloc[2:3]

# %%
df.iloc[3]['problems']
# Out:
# {'C0002871',
#  'C0018802',
#  'C0020538',
#  'C0022661',
#  'C0023518',
#  'C0036974',
#  'C0857353',
#  'C1145670'}

# %% [markdown]
# Patient with a history of St. Louis Encephalitis presents with cough of 3 days duration, fever, and loss of consciousness complicated by head trauma.

# %%
# Create a CSV for import

# Drop rows where no Assessment and Plan could be isolated
print(df.shape[0])
df_drop_empty_notes = df[df['note'] != 'No AP isolated']
print(df_drop_empty_notes.shape[0])

# Restructure the dataframe to have 1 problem per row
df_exploded = df_drop_empty_notes[['storetime', 'subject_id', 'note_id', 'problems']].explode(column='problems')
print(df_exploded.shape[0])
# Out:
# 141624
# 131121
# 786230

# %%
df_exploded.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 786230 entries, 0 to 141623
# Data columns (total 4 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   storetime   786230 non-null  object
#  1   subject_id  786230 non-null  object
#  2   note_id     786230 non-null  object
#  3   problems    779770 non-null  object
# dtypes: object(4)
# memory usage: 30.0+ MB

# %%
df_exploded[df_exploded['problems'].isnull()]
# Out:
#                   storetime subject_id note_id problems
# 54      2136-11-15 00:23:24      10174  354119      NaN
# 85      2154-03-30 09:30:57      10206  320916      NaN
# 90      2154-03-31 09:16:35      10206  321034      NaN
# 92      2154-03-31 11:35:07      10206  321051      NaN
# 110     2151-07-18 02:36:43      10302  330984      NaN
# ...                     ...        ...     ...      ...
# 141547  2157-02-23 07:06:06      99957  654757      NaN
# 141549  2157-02-23 09:54:23      99957  654790      NaN
# 141550  2157-02-23 11:28:03      99957  654815      NaN
# 141563  2180-11-29 07:06:35      99973  550825      NaN
# 141572  2181-01-30 07:42:27      99985  658018      NaN
#
# [6460 rows x 4 columns]

# %%
df_exploded[:10]
# Out:
#              storetime subject_id note_id  problems
# 0  2142-06-02 10:22:01      10134  377333  C0002871
# 0  2142-06-02 10:22:01      10134  377333  C0020538
# 0  2142-06-02 10:22:01      10134  377333  C0036974
# 0  2142-06-02 10:22:01      10134  377333  C0018802
# 0  2142-06-02 10:22:01      10134  377333  C0022661
# 0  2142-06-02 10:22:01      10134  377333  C0023518
# 0  2142-06-02 10:22:01      10134  377333  C1145670
# 0  2142-06-02 10:22:01      10134  377333  C0857353
# 1  2142-06-02 12:13:26      10134  377338  C0002871
# 1  2142-06-02 12:13:26      10134  377338  C0020538

# %%
df_exploded.dropna(inplace=True)

# %%
df_exploded[df_exploded['problems'].isnull()]
# Out:
# Empty DataFrame
# Columns: [storetime, subject_id, note_id, problems]
# Index: []

# %%
# Test imort of 10 nodes before importing the entire batch
test_import = df_exploded[:10]
test_import.to_csv('test_import.csv', index=False, encoding='utf-8')

# %%
# Write CSV to file
df_exploded.to_csv('problems_from_notes.csv', index=False, encoding='utf-8')

# Move CSV to the import folder of the database

# %%
# Create a constraint and index the Patients subject_id property
command = '''
CREATE CONSTRAINT Patient_subject_id IF NOT EXISTS
ON (n:Patients)
ASSERT n.subject_id IS UNIQUE
'''
session.run(command)

# %%
# Batch import the CSV into the database

start_time = time.time()

command = '''
USING PERIODIC COMMIT 1000 LOAD CSV WITH HEADERS FROM "file:///problems_from_notes.csv" AS csvLine
MATCH (pt:Patients {subject_id:csvLine.subject_id})
CREATE (prob:Problem {cui:csvLine.problems, datetime_reported:csvLine.storetime})
CREATE (pt)-[:HAD_PROBLEM]->(prob)
WITH prob
MATCH (c:Concept)
WHERE prob.cui = c.cui
SET prob.description = c.term
'''
session.run(command)

print("Total runtime:", time.time() - start_time, "seconds")
# Out:
# Total runtime: 63.29610276222229 seconds

# %%
# Let's do a sanity check on the 200 most common problems in the database:
command = '''MATCH (p:Problem)
RETURN p.description, p.cui, count(*) AS number 
ORDER BY number DESC
LIMIT 200'''
data = session.run(command)

pd.set_option("display.max_rows", 200)

top_problems = pd.DataFrame([dict(record) for record in data])
print(top_problems)
# Out:
#                                                                                      p.description  \
# 0                                                                       rndx infection unspecified
# 1                                                                  respiratory failure (diagnosis)
# 2                                                                                   physical wound
# 3                                                                Acute kidney failure, unspecified
# 4                                                                               anemia (diagnosis)
# 5                                              (Hypertensive disease) or (hypertension) (disorder)
# 6                                                 Body temperature above reference range (finding)
# 7                                                                  Altered mental status (finding)
# 8                                                                  atrial fibrillation (diagnosis)
# 9                                                                            rndx unspecified pain
# 10                                                                                deep; thrombosis
# 11                                                                          Leucocytosis (finding)
# 12                                                           gastrointestinal bleeding (diagnosis)
# 13                                                                           pneumonia (diagnosis)
# 14                                                                             hypoxia (diagnosis)
# 15                                                                              bleeding (symptom)
# 16                                                                             underactive thyroid
# 17                                                                      Unspecified kidney failure
# 18                                                                    thrombocytopenia (diagnosis)
# 19                                                                            Sodium [Na] overload
# 20                                                        (Septicaemia NOS) or (sepsis) (disorder)
# 21                                   Infectious systemic inflammatory response syndrome (disorder)
# 22                                                          Chronic obstructive bronchopneumopathy
# 23                                                                        Osteoarthritis (M15-M19)
# 24                                                diagnoses, syndromes, and conditions (diagnosis)
# 25                                                                                             but
# 26                                                                          Sodium [Na] deficiency
# 27                                                                               shock (diagnosis)
# 28                                                            Wiskott-Aldrich syndrome (diagnosis)
# 29                                                                      excessive fat in the blood
# 30                                                                     Diabetes mellitus (E08-E13)
# 31                                                                          high blood sugar level
# 32                                                                            Depression (finding)
# 33                                                                   Fits - convulsions (disorder)
# 34                                                              End stage renal failure (disorder)
# 35                                        (Coagulation defects) or (bleeding disorders) (disorder)
# 36                                               NEURODEGENERATION WITH BRAIN IRON ACCUMULATION 2A
# 37                                                             distressed respirations (diagnosis)
# 38                                                  MACROTHROMBOCYTOPENIA, NEPHRITIS, AND DEAFNESS
# 39                                                                               Barrett's disease
# 40                                                                            Dyspnea, unspecified
# 41                                                                                    rndx anxiety
# 42                                                            congestive heart failure (diagnosis)
# 43                                                             (Neoplasms) or (cancers) (disorder)
# 44                                                       Heart: [weak] or [failure NOS] (disorder)
# 45                                                                 benign hypertension (diagnosis)
# 46                                                                                   rndx diarrhea
# 47                                                          gastroesophageal reflux disease (GERD)
# 48                                                                 Acute brain syndrome (disorder)
# 49                                                                           bacteria in the blood
# 50                                                                   hepatic cirrhosis (diagnosis)
# 51                                                             fever of unknown origin (diagnosis)
# 52   (Disorders of fluid, electrolyte and acid-base balance) or (electrolyte disorders) (disorder)
# 53                                                                  metabolic acidosis (diagnosis)
# 54                                                              Effusion (morphologic abnormality)
# 55                                                                           pancreas Inflammation
# 56                                                                    swelling due to excess fluid
# 57                                                       rndx unspecified constipation (diagnosis)
# 58                                                       Acute-on-chronic renal failure (disorder)
# 59                                                                      Unspecified abdominal pain
# 60                                                                     pulmonary edema (diagnosis)
# 61                                                                     Agitated behavior (finding)
# 62                                                       Sleep apnoea (& [obstructive]) (disorder)
# 63                                                                       unspecified brain disease
# 64                                                                                    diabetes NOS
# 65                                                                        septic shock (diagnosis)
# 66                                                                                        Stilling
# 67                                                                     Fluid overload, unspecified
# 68                                                                              local infiltration
# 69                                                      ARDs - Acute respiratory distress syndrome
# 70                                                                         Acidosis NOS (disorder)
# 71                                                                                Cluster, Symptom
# 72                                                                aspiration pneumonia (diagnosis)
# 73                                                                    pleural effusion (diagnosis)
# 74                                                                             Ischemia (disorder)
# 75                                                                                             SCA
# 76                                                                                    thoracodynia
# 77                                                         chronic respiratory failure (diagnosis)
# 78                                                                                gout (diagnosis)
# 79                                                                           low blood sugar level
# 80                                                             Endocrine system disease (disorder)
# 81                                                                              asthma (diagnosis)
# 82                                                                                    Acute anemia
# 83                                                    Urinary tract infection (& [NOS]) (disorder)
# 84                                                         stress induced peptic ulcer (diagnosis)
# 85                                                                            Gastric Stress Ulcer
# 86                                                            Acute respiratory distress (finding)
# 87                                                                      cutaneous eruption on skin
# 88                                                                                     rndx nausea
# 89                            CVA - cerebrovascular accident (& unspecified [& stroke]) (disorder)
# 90                                                                 bacterial pneumonia (diagnosis)
# 91                                                                Simple chronic anemia (disorder)
# 92                                                                               rndx chronic pain
# 93                                                                       Diabetes mellitus (NIDDM)
# 94                                                     Fracture - lesion (morphologic abnormality)
# 95                                                                         Blood clots in the lung
# 96                                                                          Chronic kidney dis NOS
# 97                                                                                       Non STEMI
# 98                                                                   disease (or disorder); alpine
# 99                                                                        pancytopenia (diagnosis)
# 100                                                                             rndx alcohol abuse
# 101                                                          Obstruction (morphologic abnormality)
# 102                                   ([D]Debility, unspecified) or ([D] Self neglect) (situation)
# 103                                                            depression with anxiety (diagnosis)
# 104                                                            Type I diabetes mellitus (disorder)
# 105                                                             benign prostatic hyperplasia (BPH)
# 106                                                                           oliguria (diagnosis)
# 107                                                                 alcohol withdrawal (diagnosis)
# 108                                                  Atherosclerosis of coronary artery (disorder)
# 109                                                                           heart muscle disease
# 110                                                               Resolution of Pathologic Process
# 111                                                           Blood in urine (& symptom) (finding)
# 112                                                                  cardiogenic shock (diagnosis)
# 113                                                                          hemolysis (diagnosis)
# 114                                             Respiratory failure without hypercapnia (disorder)
# 115                                                             Pressure ulcer of unspecified site
# 116                                                                    hepatic failure (diagnosis)
# 117                                                                        Fibrillation (disorder)
# 118                                                                         ascites was discovered
# 119                                                                           Complaining of cough
# 120                                                                                non b hepatitis
# 121                                                              Unspecified mental disorder (F99)
# 122                                                                    rndx acute pain (diagnosis)
# 123                                                                    Hypoxic respiratory failure
# 124                                                                               sinu tachycardia
# 125                                                                                   hypotensives
# 126                                                                metabolic alkalosis (diagnosis)
# 127                                                                                           MEDS
# 128                                                                                           NETH
# 129                                                       Hepatocerebral encephalopathy (disorder)
# 130                                                                        Hemoptysis, unspecified
# 131                                                                             trauma (diagnosis)
# 132                                                                          Chronic Liver Failure
# 133                                                                                           flus
# 134                                                diabetes mellitus with ketoacidosis (diagnosis)
# 135                                                                         meningitis (diagnosis)
# 136                                                                                 epilepsy types
# 137                                                                              subdural bleeding
# 138                                                               pericardial effusion (diagnosis)
# 139                                                            coronary artery disease (diagnosis)
# 140                                                                              Bleeding in brain
# 141                                                              meningeal subarachnoid hemorrhage
# 142                                                                           dementia (diagnosis)
# 143                                                                      hypercalcemia (diagnosis)
# 144                                                                       osteoporosis (diagnosis)
# 145                                                                         cellulitis (diagnosis)
# 146                                                                                     WOUNDS INJ
# 147                                                                            abscess (diagnosis)
# 148                                                                         Complication -RETIRED-
# 149                                                                     Cholangitis NOS (disorder)
# 150                                                                       Heparin-indu thrombocyto
# 151                                                                      cholecystitis (diagnosis)
# 152                                                            cardiac rhythm disorder (diagnosis)
# 153                                                                          multiple myeloma (MM)
# 154                                                                    Collapse of lung (disorder)
# 155                                                                inflammation of the heart valve
# 156                                                                  injury from an external force
# 157                                                                          Vomiting, unspecified
# 158                                                                          back ache (diagnosis)
# 159                                                                           Hepatitis (disorder)
# 160                                                        peripheral vascular disease (diagnosis)
# 161                                                                   Normocytic anemia (disorder)
# 162                                                                          dysphagia (diagnosis)
# 163                                                                        Acute failure (finding)
# 164                                                                        Intestinal obstruct NOS
# 165                                                                         Malnutrition (E40-E46)
# 166                                                               respiratory acidosis (diagnosis)
# 167                                                           aortic valvular stenosis (diagnosis)
# 168                                                              Infarct (morphologic abnormality)
# 169                                                                       Alkalosis NOS (disorder)
# 170                                                                       Levels, High Cholesterol
# 171                                                                            obesity (diagnosis)
# 172                                                              adrenal insufficiency (diagnosis)
# 173                                                                         Neutropenia (disorder)
# 174                                                                               Ulcer (disorder)
# 175                                                             Lupus erythematosus NOS (disorder)
# 176                                                                       hematemesis was observed
# 177                                                                                stage 0 disease
# 178                       Neoplasms benign, malignant and unspecified (including cysts and polyps)
# 179                                                                             Glaucoma (H40-H42)
# 180                                                                    hematoma (physical finding)
# 181                                                                 presenile dementia (diagnosis)
# 182                                                                         Tracheobronchomalacias
# 183                                                              colon (non-specific) inflammation
# 184                                                                                     Dehydrated
# 185                                                                                  psychological
# 186                                                                             type schizophrenia
# 187                                            insufficiency; renal, acute, with necrosis, tubular
# 188                                                            hypertension caused by lung disease
# 189                                                                      renal disease (diagnosis)
# 190                                                                     rndx confusion (diagnosis)
# 191                                                          acute respiratory failure (diagnosis)
# 192                                                                        pneumonitis (diagnosis)
# 193                                                                    spreading of cancer (tumor)
# 194                                                                             headache (symptom)
# 195                                                                           Illness, unspecified
# 196                                                           Malignant lymphoma, no ICD-O subtype
# 197                                                                          hepato-renal syndrome
# 198                                                                  Hodgkin lymphoma, unspecified
# 199                                                       [D]: [fainting] or [collapse] (disorder)
#
#         p.cui  number
# 0    C0009450   41738
# 1    C1145670   27878
# 2    C0043250   26829
# 3    C0022660   22488
# 4    C0002871   20942
# 5    C0020538   19699
# 6    C0015967   15192
# 7    C0278061   13606
# 8    C0004238   10507
# 9    C0030193   10334
# 10   C0149871   10258
# 11   C0023518   10078
# 12   C0017181    8687
# 13   C0032285    8479
# 14   C0242184    7886
# 15   C0019080    7631
# 16   C0020676    7502
# 17   C0035078    7267
# 18   C0040034    7143
# 19   C0020488    6765
# 20   C0036690    6711
# 21   C0243026    6508
# 22   C0024117    5934
# 23   C0029408    5853
# 24   C0012634    5810
# 25   C0233535    5713
# 26   C0020625    5449
# 27   C0036974    5274
# 28   C0043194    5161
# 29   C0020473    4902
# 30   C0011849    4865
# 31   C0020456    4773
# 32   C0011570    4769
# 33   C0036572    4710
# 34   C0022661    4694
# 35   C0005779    4516
# 36   C0270724    4424
# 37   C0476273    4389
# 38   C0340978    4364
# 39   C0004763    4191
# 40   C0013404    4190
# 41   C0003467    3870
# 42   C0018802    3861
# 43   C0006826    3523
# 44   C0018801    3497
# 45   C0264637    3338
# 46   C0011991    3276
# 47   C0017168    3234
# 48   C0011206    3226
# 49   C0004610    3204
# 50   C0023890    3188
# 51   C0015970    3183
# 52   C0267994    3043
# 53   C0220981    2815
# 54   C0013687    2741
# 55   C0030305    2705
# 56   C0013604    2696
# 57   C0009806    2684
# 58   C0403462    2609
# 59   C0000737    2507
# 60   C0034063    2482
# 61   C0085631    2430
# 62   C0520679    2411
# 63   C0085584    2380
# 64   C0011847    2373
# 65   C0036983    2323
# 66   C1410088    2320
# 67   C0546817    2302
# 68   C0332448    2299
# 69   C0035222    2203
# 70   C0001122    2190
# 71   C0039082    2138
# 72   C0032290    2135
# 73   C0032227    2086
# 74   C0022116    2052
# 75   C0018790    2041
# 76   C0008031    2032
# 77   C0264492    2030
# 78   C0018099    1996
# 79   C0020615    1989
# 80   C0014130    1979
# 81   C0004096    1965
# 82   C0740985    1907
# 83   C0042029    1861
# 84   C2741638    1860
# 85   C0400807    1858
# 86   C0748355    1856
# 87   C0015230    1853
# 88   C0027497    1789
# 89   C0038454    1785
# 90   C0004626    1775
# 91   C0581384    1729
# 92   C0150055    1725
# 93   C0011860    1717
# 94   C0016658    1662
# 95   C0034065    1624
# 96   C1561643    1608
# 97   C1536222    1602
# 98   C0002351    1590
# 99   C0030312    1530
# 100  C0085762    1511
# 101  C0028778    1501
# 102  C3714552    1437
# 103  C0338908    1416
# 104  C0011854    1412
# 105  C1704272    1363
# 106  C0028961    1320
# 107  C0236663    1318
# 108  C0010054    1310
# 109  C0878544    1301
# 110  C1514893    1283
# 111  C0018965    1277
# 112  C0036980    1262
# 113  C0019054    1238
# 114  C0340194    1213
# 115  C0011127    1208
# 116  C0085605    1200
# 117  C0232197    1199
# 118  C0003962    1180
# 119  C0010200    1164
# 120  C0019196    1158
# 121  C0004936    1155
# 122  C0184567    1148
# 123  C3805211    1130
# 124  C0039239    1126
# 125  C0857353    1123
# 126  C0220983    1118
# 127  C3280240    1104
# 128  C0265962    1099
# 129  C0019151    1084
# 130  C0019079    1078
# 131  C3714660    1077
# 132  C0745744    1066
# 133  C0021400    1039
# 134  C0011880    1037
# 135  C0025289    1019
# 136  C0014544    1014
# 137  C0018946    1013
# 138  C0031039    1005
# 139  C1956346     998
# 140  C2937358     998
# 141  C0038525     992
# 142  C0497327     989
# 143  C0020437     988
# 144  C0029456     982
# 145  C0007642     937
# 146  C0043251     928
# 147  C0000833     920
# 148  C0009566     917
# 149  C0008311     911
# 150  C0272285     908
# 151  C0008325     906
# 152  C0003811     887
# 153  C0026764     883
# 154  C0004144     883
# 155  C0014118     883
# 156  C3263723     880
# 157  C0042963     878
# 158  C0004604     872
# 159  C0019158     869
# 160  C0085096     860
# 161  C0085577     856
# 162  C0011168     849
# 163  C0231176     847
# 164  C0021843     841
# 165  C0162429     827
# 166  C0001127     820
# 167  C0003507     820
# 168  C0021308     816
# 169  C0002063     815
# 170  C0020443     810
# 171  C0028754     806
# 172  C0001623     801
# 173  C0027947     795
# 174  C0041582     789
# 175  C0409974     789
# 176  C0018926     771
# 177  C0007099     763
# 178  C0027651     749
# 179  C0017601     747
# 180  C0018944     741
# 181  C0011265     738
# 182  C0340231     737
# 183  C0009319     731
# 184  C0011175     723
# 185  C1306597     722
# 186  C0036341     720
# 187  C0022672     713
# 188  C0020542     712
# 189  C0022658     696
# 190  C0009676     692
# 191  C0264490     688
# 192  C3714636     688
# 193  C0027627     685
# 194  C0018681     671
# 195  C0221423     667
# 196  C0024299     666
# 197  C0019212     655
# 198  C0019829     652
# 199  C0039070     650

# %%
# Further inspect problems which look suspicious or too general to be useful by looking
# up each CUI using the Metathesaurus Browser
top_problems.iloc[[24, 25, 28, 36, 38, 52, 66, 71, 98, 110, 127, 128, 195]]
# Out:
#                                                                                      p.description  \
# 24                                                diagnoses, syndromes, and conditions (diagnosis)
# 25                                                                                             but
# 28                                                            Wiskott-Aldrich syndrome (diagnosis)
# 36                                               NEURODEGENERATION WITH BRAIN IRON ACCUMULATION 2A
# 38                                                  MACROTHROMBOCYTOPENIA, NEPHRITIS, AND DEAFNESS
# 52   (Disorders of fluid, electrolyte and acid-base balance) or (electrolyte disorders) (disorder)
# 66                                                                                        Stilling
# 71                                                                                Cluster, Symptom
# 98                                                                   disease (or disorder); alpine
# 110                                                               Resolution of Pathologic Process
# 127                                                                                           MEDS
# 128                                                                                           NETH
# 195                                                                           Illness, unspecified
#
#         p.cui  number
# 24   C0012634    5810
# 25   C0233535    5713
# 28   C0043194    5161
# 36   C0270724    4424
# 38   C0340978    4364
# 52   C0267994    3043
# 66   C1410088    2320
# 71   C0039082    2138
# 98   C0002351    1590
# 110  C1514893    1283
# 127  C3280240    1104
# 128  C0265962    1099
# 195  C0221423     667

# %% [markdown]
# ### What to do with suspicious problems
#
# | Problem|Action|Reason |
# | ----|---- |
# | Disease|Delete|Too general |
# | Butting|Delete|the word "but" was likely picked up inappropriately |
# | Wiskott-Aldrich Syndrome|Delete|the word "was" was likely picked up inappropriately |
# | Infantile Neuroaxonal Dystrophy|Delete|the word "plan" was likely picked up inappropriately |
# | May-Hegglin anomaly|Delete|the word "plan" was likely picked up inappropriately |
# | Disorder of fluid AND/OR electrolyte|Delete|Too general |
# | Still|Delete|the word "still" was likely picked up inappropriately |
# | Syndrome|Delete|Too general |
# | Altitude Sickness|Change to CUI C0278061 "Abnormal mental state"|The acronym AMS triggered association with altitude sickness, but Boston is at sea level and AMS typically means "Altered Mental Status" in ICU notes |
# | physiologic resolution|Delete|Too general |
# | MICROCEPHALY, EPILEPSY, AND DIABETES SYNDROME|Delete|the word "meds" was likely picked up inappropriately |
# | Ichthyosis linearis circumflexa|Delete|the acronym "NS" was likely picked up inappropriately |

# %%
# Delete the problems marked above for deletion
delete_list = top_problems.iloc[[24, 25, 28, 36, 38, 52, 66, 71, 110, 127, 128, 195]]['p.cui'].to_list()
print(delete_list)
command = '''
MATCH (p:Problem)
WHERE p.cui IN {delete_list}
DETACH DELETE p'''.format(delete_list=delete_list)
session.run(command)
# Out:
# ['C0012634', 'C0233535', 'C0043194', 'C0270724', 'C0340978', 'C0267994', 'C1410088', 'C0039082', 'C1514893', 'C3280240', 'C0265962', 'C0221423']

# %%
# Change the "Altitude Sickness" problems to "Abnormal mental state"
command = '''
MATCH (p:Problem {cui:'C0002351'}), (c:Concept_UMLS {cui:'C0278061'})
SET p.cui = c.cui
SET p.description = c.preferred_term
'''
session.run(command)

# %%
# Finally, let's connect our new problem nodes to their respective UMLS concept nodes and the notes from which the problems were extracted

start_time = time.time()

query = '''
"MATCH (p:Problem)
MATCH (c:Concept)
WHERE p.cui = c.cui
RETURN p, c",
"CREATE (p)-[:INSTANCE_OF]->(c)"'''
command = 'CALL apoc.periodic.iterate('+query+', {batchSize:1000, parallel: true, iterateList:true})'
session.run(command)

# command = '''
# MATCH (n:Noteevents)<-[:HAD]-(pt:Patients)-[:HAD_PROBLEM]->(p:Problem)
# WHERE p.datetime_reported = n.storetime
# MERGE (n)-[:REPORTED]->(p)
# '''
# session.run(command)

print("Total runtime:", time.time() - start_time, "seconds")
# Out:
# Total runtime: 94.5746169090271 seconds

# %%
# Create a fulltext index for the description property of the nodes labeled Problem
command = '''CALL db.index.fulltext.createNodeIndex("Pt_Problems", ["Problem"], ["description"])'''
session.run(command)

# %% [markdown]
# To-Do:
# - Use Neo4J's builtin datetime functions to find the most recent nodes and to show the nodes in
# Speeding up the query:
# - First try: Create nodes for all strings and a Neo4J index the string property of each node, then set a full-text index and use it for search
# - Next try: Consider spark dataframe instead of pandas for the str_to_CUI dataframe if the above doesn't work

# %%
# Count the number of instances of each problem in a cluster of patients, and report the most frequently encountered problems 
query = '''MATCH (n:Problem) RETURN n.description AS problem, count(n.cui) AS instances ORDER BY instances DESC'''
PL = session.run(query)
ordered_prob_list = pd.DataFrame([dict(record) for record in PL])
ordered_prob_list[:20]
# Out:
#                                           problem  instances
# 0                             Respiratory Failure         24
# 1                             Atrial Fibrillation         22
# 2                              Presenile dementia         21
# 3                                   Heart failure         21
# 4                             Metabolic alkalosis         17
# 5                                  Hypothyroidism         15
# 6                              Pulmonary Embolism         14
# 7                           Kidney Failure, Acute         12
# 8                           Communicable Diseases          7
# 9                                         Butting          7
# 10                 Benign hypertension (disorder)          7
# 11                           Hypertensive disease          5
# 12                                     Bacteremia          5
# 13                       Congestive heart failure          4
# 14  MICROCEPHALY, EPILEPSY, AND DIABETES SYNDROME          4
# 15                          Mass of thyroid gland          4
# 16    Pathological accumulation of air in tissues          4
# 17                 Paroxysmal atrial fibrillation          4
# 18                                        Hypoxia          3
# 19                          Diastolic dysfunction          3

# %%
session.close()
