# %% [markdown]
# Orphanet has Creative Commons-licensed data that we can use to identify patients with rare diseases.
#
# HOOM is a module that qualifies the annotation between a clinical entity and phenotypic abnormalities according to a frequency and by integrating the notion of diagnostic criterion. See info on HOOM [here](http://www.orphadata.org/cgi-bin/img/PDF/WhatIsHOOM.pdf).

# %% [markdown]
# ## Importing HOOM data into the knowledge graph
#
# Importing OWL files into Neo4j:
# https://neo4j.com/labs/neosemantics/4.0/importing-ontologies/
#
# Mapping ORDO entities to UMLS concepts

# %%
import pandas as pd

# %%
ORDOdata = pd.read_csv('ORDO.csv')
ORDOdata
# Out:
#                                         Class ID  \
# 0        http://www.orpha.net/ORDO/Orphanet_1390
# 1      http://www.orpha.net/ORDO/Orphanet_119213
# 2      http://www.orpha.net/ORDO/Orphanet_264694
# 3       http://www.orpha.net/ORDO/Orphanet_69735
# 4         http://www.orpha.net/ORDO/Orphanet_454
# ...                                          ...
# 15200    http://www.orpha.net/ORDO/Orphanet_2064
# 15201    http://www.orpha.net/ORDO/Orphanet_1011
# 15202   http://www.orpha.net/ORDO/Orphanet_83620
# 15203  http://www.orpha.net/ORDO/Orphanet_276630
# 15204  http://www.orpha.net/ORDO/Orphanet_238536
#
#                                          Preferred Label  \
# 0      Night blindness-skeletal anomalies-dysmorphism...
# 1                                  CCM2 scaffold protein
# 2          Interstitial lung disease specific to infancy
# 3      Hypotrichosis-lymphedema-telangiectasia-renal ...
# 4                                    Acquired ichthyosis
# ...

# %%
ORDOdata[ORDOdata['CUI'].notnull()]
# Out:
# Empty DataFrame
# ...

# %%
HOOMdata = pd.read_csv('HOOM.csv')
HOOMdata
# Out:
# /home/tim/anaconda3/envs/jupyter_env/lib/python3.9/site-packages/IPython/core/interactiveshell.py:3165: DtypeWarning: Columns (19,20) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#                                                  Class ID  \
# 0       http://www.semanticweb.org/ontology/HOOM#Orpha...
# 1       http://www.semanticweb.org/ontology/HOOM#Orpha...
# 2       http://www.semanticweb.org/ontology/HOOM#Orpha...
# 3       http://www.semanticweb.org/ontology/HOOM#Orpha...
# 4                 http://www.orpha.net/ORDO/Orphanet_1390
# ...                                                   ...
# 131759  http://www.semanticweb.org/ontology/HOOM#Orpha...
# 131760          http://purl.obolibrary.org/obo/HP_0003760
# 131761  http://www.semanticweb.org/ontology/HOOM#Orpha...
# 131762  http://www.semanticweb.org/ontology/HOOM#Orpha...
# 131763  http://www.semanticweb.org/ontology/HOOM#Orpha...
# ...

# %%
HOOMdata['Preferred Label'] = HOOMdata['Preferred Label'].str.split('_')

# %%
HOOMdata['Preferred Label']
# Out:
# 0            [Orpha:239, HP:0002812, Freq:OC]
# 1         [Orpha:255210, HP:0031546, Freq:OC]
# 2         [Orpha:314389, HP:0000767, Freq:VF]
# 3          [Orpha:141184, HP:0031449, Freq:F]
# 4                                [ORPHA:1390]
#                          ...
# 131759    [Orpha:494424, HP:0032169, Freq:OC]
# 131760                           [HP:0003760]
# 131761      [Orpha:90321, HP:0002355, Freq:F]
# 131762     [Orpha:77259, HP:0000790, Freq:OC]
# 131763      [Orpha:1163, HP:0000925, Freq:VR]
# Name: Preferred Label, Length: 131764, dtype: object

# %%
HOOMdata2 = pd.DataFrame(HOOMdata['Preferred Label'].tolist())
HOOMdata2 = HOOMdata2.iloc[:,:3]

# %%
HOOMdata2[2].value_counts().head(20)
# Out:
# Freq:OC          41616
# Freq:F           38062
# Freq:VF          26494
# Freq:VR           6442
# Crit:E             706
# Freq:O             609
# PMID:20301507        4
# PMID:20301578        3
# PMID:20537182        3
# PMID:29768628        2
# PMID:26000153        2
# PMID:26089585        2
# PMID:26416826        2
# PMID:25719194        2
# PMID:20301663        2
# PMID:1601005         2
# PMID:21967988        2
# PMID:24836204        2
# PMID:23778136        2
# PMID:27862579        2
# Name: 2, dtype: int64

# %%
HOOMdata2[HOOMdata2[1].str.contains('CUI')]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-64-9d7ac83b33fc> in <module>
# ----> 1 data2[data2[2].str.contains('CUI')]
#
# ~/anaconda3/envs/jupyter_env/lib/python3.9/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    3012
#    3013         # Do we have a (boolean) 1d indexer?
# -> 3014         if com.is_bool_indexer(key):
#    3015             return self._getitem_bool_array(key)
#    3016
#
# ~/anaconda3/envs/jupyter_env/lib/python3.9/site-packages/pandas/core/common.py in is_bool_indexer(key)
#     112                     # Don't raise on e.g. ["A", "B", np.nan], see
#     113                     #  test_loc_getitem_list_of_labels_categoricalindex_with_na
# --> 114                     raise ValueError(na_msg)
#     115                 return False
#     116             return True
#
# ...

# %%
from rdflib import Graph

g = Graph()
g.parse("owlapi.xrdf", format='xml')

print(len(g))
# prints: 2

g.serialize(destination="HOOM.ttl")
# Out:
# 3453428

# %%
g.serialize(destination="ORDO.ttl")
# Out:
# <Graph identifier=N1a0cf9681e77422781181a5e92682e1f (<class 'rdflib.graph.Graph'>)>

# %%
from rdflib import Graph

g = Graph()
g.parse("demo.owl", format='n3')

print(len(g))
# prints: 2

import pprint
for stmt in g:
    pprint.pprint(stmt)

g.serialize(destination="ORDO.ttl")
# Out:
# 2
# (rdflib.term.URIRef('http://example.com/drewp'),
#  rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'),
#  rdflib.term.URIRef('http://xmlns.com/foaf/0.1/Person'))
# (rdflib.term.URIRef('http://example.com/drewp'),
#  rdflib.term.URIRef('http://example.com/says'),
#  rdflib.term.Literal('Hello World'))
# <Graph identifier=N44df756100b844a5a0a91968e251ac3b (<class 'rdflib.graph.Graph'>)>
